# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt

# %%
(train_images,train_labels),(test_images,test_lables)=datasets.cifar10.load_data()
print(train_image.shape,' ',train_labels.shape)
train_images,test_images=train_images/255.0,test_images/255.0
class_name=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
plt.Figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i],cmap=plt.cm.binary)
    plt.xlabel(class_name[train_labels[i][0]])
plt.show()
# Out:
# (50000, 32, 32, 3)   (50000, 1)

# %%
model=models.Sequential()
model.add(layers.Conv2D(input_shape=(32,32,3),filters=32,kernel_size=(3,3),strides=(1,1),padding='valid',activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),padding='valid',activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),padding='valid',activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(128,activation='relu'))
model.add(layers.Dense(10))

# %%
model.compile(optimizer='adam',loss=tkeras.losses.SparseCategoricalCrossentropy(from_logit=True),metrics=['accuracy'])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\NINGLIK\school\bigDataAnalysis\c.ipynb 单元格 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/NINGLIK/school/bigDataAnalysis/c.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> model.compile(optimizer='adam',loss=tf.losses.SparseCategoricalCrossentropy(from_logit=True),metrics=['accuracy'])
#       <a href='vscode-notebook-cell:/c%3A/NINGLIK/school/bigDataAnalysis/c.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> model.summary()
#
# TypeError: SparseCategoricalCrossentropy.__init__() got an unexpected keyword argument 'from_logit'

# %%
history=model.fit(train_images,train_labels,epochs=10,validation_data=())
